# %%
import os
import numpy as np
import itertools
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
df15 = pd.read_csv("../../Dataset/28-02-2018(Time).csv", low_memory = False)
df15 = df15.drop([0,1])
df15['Timestamp']= pd.to_datetime(df15['Timestamp'])
df15 = df15.sort_values(by=['Timestamp'])
df15 = df15.drop(columns = ['Timestamp'])

# %%
df15
# Out:
#        Fwd PSH Flags Bwd PSH Flags Fwd URG Flags Bwd URG Flags FIN Flag Cnt  \
# 352143             0             0             0             0            0
# 364088             0             0             0             0            0
# 207898             0             0             0             0            0
# 221098             0             0             0             0            0
# 232490             0             0             0             0            0
# ...              ...           ...           ...           ...          ...
# 207897             0             0             0             0            0
# 500032             0             0             0             0            0
# 488997             0             0             0             0            0
# 496254             0             0             0             0            0
# 122091             0             0             0             0            0
#
#        SYN Flag Cnt RST Flag Cnt PSH Flag Cnt ACK Flag Cnt URG Flag Cnt  ...  \
# 352143            0            0            1            0            0  ...
# 364088            0            0            0            0            0  ...
# 207898            0            1            1            0            0  ...
# 221098            0            0            0            0            0  ...
# 232490            0            1            1            0            0  ...
# ...             ...          ...          ...          ...          ...  ...
# 207897            0            0            0            1            0  ...
# 500032            0            0            0            0            0  ...
# 488997            0            1            1            0            0  ...
# 496254            0            0            1            0            0  ...
# 122091            0            0            1            0            0  ...
#
#        Fwd Act Data Pkts Fwd Seg Size Min Active Mean Active Std Active Max  \
# 352143                 0               20           0          0          0
# 364088                 0                0           0          0          0
# 207898                 5               20           0          0          0
# 221098                 0                8           0          0          0
# 232490                 6               20           0          0          0
# ...                  ...              ...         ...        ...        ...
# 207897                 0               20           0          0          0
# 500032                 0                8           0          0          0
# 488997                 6               20           0          0          0
# 496254                 5               20           0          0          0
# 122091                 5               20           0          0          0
#
#        Active Min Idle Mean       Idle Std  Idle Max  Idle Min
# 352143          0         0              0         0         0
# 364088          0  56320368  18.3847763109  56320381  56320355
# 207898          0         0              0         0         0
# 221098          0         0              0         0         0
# 232490          0         0              0         0         0
# ...           ...       ...            ...       ...       ...
# 207897          0         0              0         0         0
# 500032          0         0              0         0         0
# 488997          0         0              0         0         0
# 496254          0         0              0         0         0
# 122091          0         0              0         0         0
#
# [606902 rows x 79 columns]

# %%
df16Aux = pd.read_csv("../../Dataset/01-03-2018(Time).csv", low_memory = False)
df16Aux = df16Aux.drop([0,1])
df16Aux['Timestamp']= pd.to_datetime(df16Aux['Timestamp'])
df16Aux = df16Aux.sort_values(by=['Timestamp'])
df16Aux = df16Aux.drop(columns = ['Timestamp'])

# %%
listOrd = df15.columns.tolist()
df16 = pd.DataFrame()
for colu in listOrd:
    df16[colu] = df16Aux[colu]

# %%
df16Aux = None

# %%
df16
# Out:
#        Fwd PSH Flags Bwd PSH Flags Fwd URG Flags Bwd URG Flags FIN Flag Cnt  \
# 94151              0             0             0             0            0
# 36517              0             0             0             0            0
# 94152              0             0             0             0            0
# 78853              0             0             0             0            0
# 94153              0             0             0             0            0
# ...              ...           ...           ...           ...          ...
# 92534              0             0             0             0            0
# 92533              0             0             0             0            0
# 328181             0             0             0             0            0
# 328182             0             0             0             0            0
# 11607              0             0             0             0            0
#
#        SYN Flag Cnt RST Flag Cnt PSH Flag Cnt ACK Flag Cnt URG Flag Cnt  ...  \
# 94151             0            1            1            0            0  ...
# 36517             0            1            1            0            0  ...
# 94152             0            0            0            0            0  ...
# 78853             0            0            1            0            0  ...
# 94153             0            0            0            0            0  ...
# ...             ...          ...          ...          ...          ...  ...
# 92534             0            0            0            0            0  ...
# 92533             0            0            0            0            0  ...
# 328181            0            1            1            0            0  ...
# 328182            0            0            0            1            0  ...
# 11607             0            1            1            0            0  ...
#
#        Fwd Act Data Pkts Fwd Seg Size Min  Active Mean   Active Std  \
# 94151                  5               20            0            0
# 36517                  5               20            0            0
# 94152                  0                8            0            0
# 78853                  0               20            0            0
# 94153                  8                8  355986.2857  38365.00373
# ...                  ...              ...          ...          ...
# 92534                  5                8      4000689            0
# 92533                  5                8      4000684            0
# 328181                 7               20            0            0
# 328182                 0               20            0            0
# 11607                  5               20            0            0
#
#        Active Max Active Min Idle Mean     Idle Std  Idle Max  Idle Min
# 94151           0          0         0            0         0         0
# 36517           0          0         0            0         0         0
# 94152           0          0         0            0         0         0
# 78853           0          0         0            0         0         0
# 94153      425798     316056  14700000  41073.02896  14700000  14600000
# ...           ...        ...       ...          ...       ...       ...
# 92534     4000689    4000689  21400000     15300000  42000000   7200659
# 92533     4000684    4000684  21400000     15300000  42000000   7200667
# 328181          0          0         0            0         0         0
# 328182          0          0  86600000            0  86600000  86600000
# 11607           0          0         0            0         0         0
#
# [328181 rows x 79 columns]

# %%
input_label15 = np.array(df15.loc[:, df15.columns != "Label"]).astype(np.float)
output_label15 = np.array(df15["Label"])
out = []
for o in output_label15:
    if(o == "Benign"):out.append(0)
    else: out.append(1)
output_label15= out

# %%
input_label16 = np.array(df16.loc[:, df16.columns != "Label"]).astype(np.float)
output_label16 = np.array(df16["Label"])
out = []
for o in output_label16:
    if(o == "Benign"):out.append(0)
    else: out.append(1)
output_label16 = out

# %%
dfAE = pd.concat([df15, df16])
input_labelAE = np.array(dfAE.loc[:, dfAE.columns != "Label"]).astype(np.float)
output_labelAE = np.array(dfAE["Label"])
out = []
for o in output_labelAE:
    if(o == "Benign"):out.append(0)
    else: out.append(1)
output_labelAE = out

# %%
dfAE = None
df15 = None
df16 = None
out = None

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaler.fit(input_labelAE)
input_label15 = scaler.transform(input_label15)
input_label16 = scaler.transform(input_label16)
input_labelAE = scaler.transform(input_labelAE)

# %% [markdown]
# ## AutoEncoder

# %%
input_labelAE, output_labelAE = shuffle(input_labelAE, output_labelAE)

# %%
inp_train,inp_test,out_train,out_test = train_test_split(input_labelAE, input_labelAE, test_size=0.2)

# %%
input_model = keras.layers.Input(shape = (78,))
enc = keras.layers.Dense(units = 64, activation = "relu", use_bias = True)(input_model)
enc = keras.layers.Dense(units = 36, activation = "relu", use_bias = True)(enc)
enc = keras.layers.Dense(units = 18, activation = "relu")(enc)
dec = keras.layers.Dense(units = 36, activation = "relu", use_bias = True)(enc)
dec = keras.layers.Dense(units = 64, activation = "relu", use_bias = True)(dec)
dec = keras.layers.Dense(units = 78, activation = "relu", use_bias = True)(dec)
auto_encoder = keras.Model(input_model, dec)

# %%
encoder = keras.Model(input_model, enc)
decoder_input = keras.layers.Input(shape = (18,))
decoder_layer = auto_encoder.layers[-3](decoder_input)
decoder_layer = auto_encoder.layers[-2](decoder_layer)
decoder_layer = auto_encoder.layers[-1](decoder_layer)
decoder = keras.Model(decoder_input, decoder_layer)

# %%
auto_encoder.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00025), loss = "mean_squared_error", metrics = ['accuracy'])

# %%
train = auto_encoder.fit(x = np.array(inp_train), y = np.array(out_train),validation_split= 0.1, epochs = 10, verbose = 1, shuffle = True)
# Out:
# Epoch 1/10
# 21040/21040 [==============================] - 26s 1ms/step - loss: 0.0054 - accuracy: 0.7755 - val_loss: 0.0041 - val_accuracy: 0.73090s - loss: 0.0063 - accurac - ETA: 10 - ETA: 8s - loss: 0.0060 - accu - ETA: 8s - loss: 0.0060 - accura - ETA: 7s - loss: 0.0060 - accura - ETA: 7s - loss: 0.0059 - accura - ETA: 6s - loss: 0.0 - ETA: 5s - loss: 0.0058 - accura - ETA: 2s - loss: 0.0056 - accuracy: 0.77 - ETA: 2s - - ETA: 1s - loss: 0.0055 - accuracy: 0. - ETA: 1s - loss: 0.0055 - accuracy - ETA: 1s - l - ETA: 0s - loss: 0.0055 - accuracy: 0. - ETA: 0s - loss: 0.0055 - accu
# Epoch 2/10
# 21040/21040 [==============================] - 22s 1ms/step - loss: 0.0040 - accuracy: 0.8064 - val_loss: 0.0013 - val_accuracy: 0.7689A: 0s - loss: 0.0041 - accuracy - ETA: 0s - loss: 0.0041 -
# Epoch 3/10
# 21040/21040 [==============================] - 24s 1ms/step - loss: 0.0012 - accuracy: 0.7679 - val_loss: 0.0012 - val_accuracy: 0.8802
# Epoch 4/10
# 21040/21040 [==============================] - 24s 1ms/step - loss: 0.0012 - accuracy: 0.7666 - val_loss: 0.0012 - val_accuracy: 0.7442
# Epoch 5/10
# 21040/21040 [==============================] - 23s 1ms/step - loss: 0.0012 - accuracy: 0.7652 - val_loss: 0.0012 - val_accuracy: 0.7707
# Epoch 6/10
# 21040/21040 [==============================] - 23s 1ms/step - loss: 0.0012 - accuracy: 0.7621 - val_loss: 0.0012 - val_accuracy: 0.7091TA: 10s - loss: 0.001 - ETA: 9s - loss: 0.0012 -  - ETA: 9s - E - ETA: 5s - loss: 0.0012 - ac - ETA: 5s - loss: 0.0012 - accuracy: 0. - ETA: 5s - loss: 0.0012  - ETA: 5s - loss: 0.0012 - accuracy: 0.76 - ETA: 4s - loss: 0.0012 - accuracy - ETA: 3s - loss: 0.0012 - accuracy: 0.76 - ETA: 3s - loss: 0.0012 - accuracy: 0. - ETA: 3s - loss: 0.0012 - accuracy: 0. - ETA: 3s - loss: 0.0012 - accuracy: 0.76 - ETA: 3s - loss: 0.0012 - accuracy: 0.76 - ETA: 3s - loss: 0.001 - ETA: 2s - loss: 0.0012 - ac - ETA: 2s - loss: 0.0012 - accuracy: 0. - ETA: 2s - loss: 0.0012 - accuracy: 0. - ETA: 2s - loss: 0.0012 - accuracy: 0.76 - ETA: 2s - loss: 0.0012 - accuracy - ETA: 1s - loss: 0.0012 - accuracy - ETA: 1s - loss: 0.0012 - accuracy: 0.76 - ETA: 1s - loss: 0.0 - ETA: 1s - loss: 0.0012 - accu - ETA: 0s -
# Epoch 7/10
# 21040/21040 [==============================] - 24s 1ms/step - loss: 0.0012 - accuracy: 0.7616 - val_loss: 0.0012 - val_accuracy: 0.7733
# Epoch 8/10
# 21040/21040 [==============================] - 26s 1ms/step - loss: 0.0012 - accuracy: 0.7624 - val_loss: 0.0012 - val_accuracy: 0.8214
# Epoch 9/10
# 21040/21040 [==============================] - 25s 1ms/step - loss: 0.0012 - accuracy: 0.7638 - val_loss: 0.0012 - val_accuracy: 0.7965
# Epoch 10/10
# 21040/21040 [==============================] - 25s 1ms/step - loss: 0.0012 - accuracy: 0.7633 - val_loss: 0.0012 - val_accuracy: 0.7412

# %%
predict = auto_encoder.predict(inp_test)
losses = keras.losses.mean_squared_error(out_test, predict).numpy()
total = 0
for loss in losses:
    total += loss
print(total / len(losses))
# Out:
# 0.0011591887712524983

# %%
inp_train = None
inp_test = None
out_train = None
out_test = None
input_labelAE = None

# %%
input_label15 = encoder.predict(input_label15)
input_label16 = encoder.predict(input_label16)

# %%
tamanhoSequencia = 10

# %%
inp = []
out = []
num = 0
for i in range(len(input_label15) - tamanhoSequencia + 1):
    aux = []
    for j in range(i, i + tamanhoSequencia):
        aux.append(input_label15[j])
    inp.append(aux)
    out.append(output_label15[i + tamanhoSequencia - 1])
input_label15 = inp
output_label15 = out

# %%
inp = []
out = []
num = 0
for i in range(len(input_label16) - tamanhoSequencia + 1):
    aux = []
    for j in range(i, i + tamanhoSequencia):
        aux.append(input_label16[j])
    inp.append(aux)
    out.append(output_label16[i + tamanhoSequencia - 1])
input_label16 = inp
output_label16 = out

# %%
inp = None
out = None

# %% [markdown]
# ## Classificador

# %%
model = keras.Sequential([
    keras.layers.LSTM(units = 16, input_shape = ((tamanhoSequencia,18)), return_sequences = True, use_bias = True),
    keras.layers.LSTM(units = 8, return_sequences = False, use_bias = True),
    keras.layers.Dense(units = 2, activation = "softmax")
])
model.compile(optimizer= keras.optimizers.Adam(lr= 0.00025), loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
model.fit(x = np.array(input_label15), y = np.array(output_label15), validation_split= 0.1, epochs = 10, verbose = 1)
# Out:
# Epoch 1/10
# 17069/17069 [==============================] - 102s 6ms/step - loss: 0.3558 - accuracy: 0.8855 - val_loss: 0.3715 - val_accuracy: 0.8749
# Epoch 2/10
# 17069/17069 [==============================] - 98s 6ms/step - loss: 0.3438 - accuracy: 0.8884 - val_loss: 0.3743 - val_accuracy: 0.8749
# Epoch 3/10
# 17069/17069 [==============================] - 99s 6ms/step - loss: 0.3415 - accuracy: 0.8886 - val_loss: 0.3760 - val_accuracy: 0.8749
# Epoch 4/10
# 17069/17069 [==============================] - 98s 6ms/step - loss: 0.3396 - accuracy: 0.8890 - val_loss: 0.3759 - val_accuracy: 0.8749
# Epoch 5/10
# 17069/17069 [==============================] - 97s 6ms/step - loss: 0.3384 - accuracy: 0.8890 - val_loss: 0.3740 - val_accuracy: 0.8749
# Epoch 6/10
# 17069/17069 [==============================] - 96s 6ms/step - loss: 0.3376 - accuracy: 0.8890 - val_loss: 0.3738 - val_accuracy: 0.8749
# Epoch 7/10
# 17069/17069 [==============================] - 98s 6ms/step - loss: 0.3365 - accuracy: 0.8890 - val_loss: 0.3715 - val_accuracy: 0.8749
# Epoch 8/10
# 17069/17069 [==============================] - 98s 6ms/step - loss: 0.3356 - accuracy: 0.8891 - val_loss: 0.3765 - val_accuracy: 0.8749
# Epoch 9/10
# 17069/17069 [==============================] - 98s 6ms/step - loss: 0.3370 - accuracy: 0.8881 - val_loss: 0.3704 - val_accuracy: 0.8749
# Epoch 10/10
# 17069/17069 [==============================] - 97s 6ms/step - loss: 0.3346 - accuracy: 0.8890 - val_loss: 0.3683 - val_accuracy: 0.8749

# %%
input_label15 = None
output_label15 = None

# %%
resu = model.predict(np.array(input_label16))

# %%
res = [np.argmax(r) for r in resu]

# %%
cm = confusion_matrix(y_true = np.array(output_label16).reshape(len(output_label16)), y_pred = np.array(res))

# %%
def plot_confusion_matrix(cm, classes, normaliza = False, title = "Confusion matrix", cmap = plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normaliza:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print("Confusion matrix, without normalization")
    
    print(cm)
    
    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i,j] > thresh else "black")
    
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
labels = ["Benign", "Dos"]
plot_confusion_matrix(cm = cm, classes = labels, title = "Dos IDS")
# Out:
# Confusion matrix, without normalization
# [[235769      0]
#  [ 92403      0]]

# %%
output_label16 = np.array(output_label16).reshape(len(output_label16))
res = np.array(res)
fpr, tpr, _ = roc_curve(output_label16,  res)
auc = roc_auc_score(output_label16, res)

# %%
plt.plot(fpr, tpr, label="auc=" + str(auc))
plt.legend(loc=4)
plt.show()
